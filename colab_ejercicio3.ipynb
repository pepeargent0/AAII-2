# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown
import zipfile

# Descargar el archivo desde Google Drive
gdown.download("https://drive.google.com/uc?id=1Pqs5Y6dZr4R66Dby5hIUIjPZtBI28rmJ", "dataset.zip", quiet=False)

# Extraer el contenido del ZIP
with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
    zip_ref.extractall()
    print("Dataset extraído exitosamente.")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Pqs5Y6dZr4R66Dby5hIUIjPZtBI28rmJ
# From (redirected): https://drive.google.com/uc?id=1Pqs5Y6dZr4R66Dby5hIUIjPZtBI28rmJ&confirm=t&uuid=54bd6049-8524-4936-aeb6-fef19b1835d1
# To: /content/dataset.zip
# 100%|██████████| 363M/363M [00:10<00:00, 33.8MB/s]
# Dataset extraído exitosamente.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Add
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import Precision, Recall, AUC

def is_directory_empty(directory):
    """Verifica si un directorio está vacío."""
    if not os.path.exists(directory):
        print(f"El directorio {directory} no existe.")
        return True
    return len(os.listdir(directory)) == 0

class SceneClassifier:
    def __init__(self, train_dir, test_dir, pred_dir, target_size=(150, 150), batch_size=32):
        self.train_dir = train_dir
        self.test_dir = test_dir
        self.pred_dir = pred_dir
        self.target_size = target_size
        self.batch_size = batch_size
        self.models = {}
        self.history = {}

    def load_data(self):
      """Carga y preprocesa los datos."""
      train_datagen = ImageDataGenerator(rescale=1.0 / 255)
      test_datagen = ImageDataGenerator(rescale=1.0 / 255)

      # Cargar los datos de entrenamiento y prueba
      self.train_generator = train_datagen.flow_from_directory(
          self.train_dir, target_size=self.target_size, batch_size=self.batch_size, class_mode='categorical'
      )
      self.test_generator = test_datagen.flow_from_directory(
          self.test_dir, target_size=self.target_size, batch_size=self.batch_size, class_mode='categorical'
      )

      # Verificar si el directorio de predicción tiene imágenes
      if is_directory_empty(self.pred_dir):
          print("No hay datos de predicción disponibles.")
          self.prediction_generator = None
      else:
          self.prediction_generator = test_datagen.flow_from_directory(
              self.pred_dir, target_size=self.target_size, batch_size=self.batch_size, class_mode=None, shuffle=False
          )
      print("Datos cargados exitosamente.")



    def build_dense_model(self):
        """Construye un modelo denso."""
        model = Sequential([
            Flatten(input_shape=(*self.target_size, 3)),
            Dense(128, activation='relu'),
            Dense(6, activation='softmax')
        ])
        self._compile_model(model, 'dense')

    def build_cnn_model(self):
        """Construye un modelo CNN."""
        model = Sequential([
            Conv2D(32, (3, 3), activation='relu', input_shape=(*self.target_size, 3)),
            MaxPooling2D((2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(6, activation='softmax')
        ])
        self._compile_model(model, 'cnn')

    def build_residual_model(self):
        """Construye un modelo con bloque residual."""
        input_layer = Input(shape=(*self.target_size, 3))

        # Transformamos la entrada para que coincida con las dimensiones de salida
        x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
        x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)

        # Ajustamos la dimensión del input_layer para que coincida con 'x' usando una convolución 1x1
        input_transformed = Conv2D(32, (1, 1), padding='same')(input_layer)

        # Realizamos la suma (residual connection)
        residual = Add()([input_transformed, x])

        # Resto del modelo
        x = Flatten()(residual)
        output_layer = Dense(6, activation='softmax')(x)

        model = Model(inputs=input_layer, outputs=output_layer)
        self._compile_model(model, 'residual')


    def build_transfer_model(self):
        """Construye un modelo con transfer learning usando VGG16."""
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=(*self.target_size, 3))
        base_model.trainable = False

        model = Sequential([
            base_model,
            Flatten(),
            Dense(128, activation='relu'),
            Dense(6, activation='softmax')
        ])
        self._compile_model(model, 'transfer')

    def _compile_model(self, model, name):
        """Compila el modelo con las métricas necesarias."""
        model.compile(optimizer='adam', loss='categorical_crossentropy',
                      metrics=['accuracy', Precision(name='precision'), Recall(name='recall'), AUC(name='auc')])
        self.models[name] = model

    def train(self, model_name, epochs=5):
        """Entrena un modelo específico."""
        model = self.models[model_name]
        history = model.fit(self.train_generator, epochs=epochs, validation_data=self.test_generator)
        self.history[model_name] = history

    def evaluate(self, model_name):
        """Evalúa un modelo y muestra las métricas detalladas."""
        model = self.models[model_name]
        y_true = self.test_generator.classes
        y_pred = np.argmax(model.predict(self.test_generator), axis=1)

        print(f"Resultados para {model_name}:")
        print(classification_report(y_true, y_pred, target_names=self.test_generator.class_indices.keys()))

        ConfusionMatrixDisplay.from_predictions(y_true, y_pred, display_labels=self.test_generator.class_indices.keys())
        plt.show()


    def predict(self, model_name):
      """Realiza predicciones sobre el conjunto de predicción."""
      if self.prediction_generator is None:
          print("No se puede realizar predicción: No hay datos de predicción disponibles.")
          return

      model = self.models[model_name]
      predictions = model.predict(self.prediction_generator)
      predicted_classes = np.argmax(predictions, axis=1)

      print(f"Predicciones para {model_name}: {predicted_classes}")
      return predicted_classes


    def plot_history(self, model_name):
        """Grafica la pérdida y precisión."""
        history = self.history[model_name]

        plt.figure(figsize=(14, 5))

        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Pérdida Entrenamiento')
        plt.plot(history.history['val_loss'], label='Pérdida Validación')
        plt.title(f'{model_name} - Pérdida')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Precisión Entrenamiento')
        plt.plot(history.history['val_accuracy'], label='Precisión Validación')
        plt.title(f'{model_name} - Precisión')
        plt.legend()

        plt.show()

# %%
# Instancia del clasificador
classifier = SceneClassifier(
    train_dir='seg_train/seg_train',
    test_dir='seg_test/seg_test',
    pred_dir='seg_pred/seg_pred'
)

# Cargar los datos
classifier.load_data()

# Construir los modelos
classifier.build_dense_model()
classifier.build_cnn_model()
classifier.build_residual_model()
# classifier.build_transfer_model()

# Entrenar y evaluar los modelos
for model_name in classifier.models.keys():
    classifier.train(model_name, epochs=200)
    classifier.evaluate(model_name)
    classifier.plot_history(model_name)

# Realizar predicciones solo si hay datos disponibles
for model_name in classifier.models.keys():
    classifier.predict(model_name)
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.
# Found 0 images belonging to 0 classes.
# Datos cargados exitosamente.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step - accuracy: 0.3361 - auc: 0.6618 - loss: 8.6548 - precision: 0.3566 - recall: 0.3073 - val_accuracy: 0.4000 - val_auc: 0.7028 - val_loss: 2.4552 - val_precision: 0.4278 - val_recall: 0.3720
# Epoch 2/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 37s 37ms/step - accuracy: 0.4550 - auc: 0.7806 - loss: 1.6377 - precision: 0.5414 - recall: 0.3553 - val_accuracy: 0.3337 - val_auc: 0.6928 - val_loss: 1.5835 - val_precision: 0.6078 - val_recall: 0.1983
# Epoch 3/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.3116 - auc: 0.6953 - loss: 1.5371 - precision: 0.7631 - recall: 0.1563 - val_accuracy: 0.3790 - val_auc: 0.7656 - val_loss: 1.4617 - val_precision: 0.6938 - val_recall: 0.1223
# Epoch 4/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 22s 43ms/step - accuracy: 0.4077 - auc: 0.7727 - loss: 1.4264 - precision: 0.7500 - recall: 0.1555 - val_accuracy: 0.3723 - val_auc: 0.7220 - val_loss: 1.5245 - val_precision: 0.8299 - val_recall: 0.0813
# Epoch 5/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 0.4036 - auc: 0.7513 - loss: 1.4706 - precision: 0.8202 - recall: 0.0997 - val_accuracy: 0.3863 - val_auc: 0.7595 - val_loss: 1.4780 - val_precision: 0.8920 - val_recall: 0.0743
# Epoch 6/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.3904 - auc: 0.7646 - loss: 1.4615 - precision: 0.8468 - recall: 0.0875 - val_accuracy: 0.3833 - val_auc: 0.7594 - val_loss: 1.4729 - val_precision: 0.9322 - val_recall: 0.0733
# Epoch 7/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 0.4018 - auc: 0.7777 - loss: 1.4136 - precision: 0.8506 - recall: 0.1166 - val_accuracy: 0.3743 - val_auc: 0.7560 - val_loss: 1.4726 - val_precision: 0.7590 - val_recall: 0.1270
# Epoch 8/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.4187 - auc: 0.7927 - loss: 1.3814 - precision: 0.8015 - recall: 0.1548 - val_accuracy: 0.3770 - val_auc: 0.7639 - val_loss: 1.4614 - val_precision: 0.7305 - val_recall: 0.1157
# Epoch 9/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.4241 - auc: 0.7897 - loss: 1.3777 - precision: 0.8002 - recall: 0.1533 - val_accuracy: 0.3743 - val_auc: 0.7659 - val_loss: 1.4342 - val_precision: 0.8899 - val_recall: 0.1023
# Epoch 10/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.4660 - auc: 0.8120 - loss: 1.3128 - precision: 0.7702 - recall: 0.2161 - val_accuracy: 0.2760 - val_auc: 0.6833 - val_loss: 1.6119 - val_precision: 0.8584 - val_recall: 0.0323
# Epoch 11/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.4355 - auc: 0.8014 - loss: 1.3511 - precision: 0.8166 - recall: 0.1469 - val_accuracy: 0.4027 - val_auc: 0.7730 - val_loss: 1.4638 - val_precision: 0.5964 - val_recall: 0.2423
# Epoch 12/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5116 - auc: 0.8353 - loss: 1.2463 - precision: 0.7344 - recall: 0.2893 - val_accuracy: 0.4990 - val_auc: 0.8179 - val_loss: 1.3194 - val_precision: 0.7072 - val_recall: 0.2520
# Epoch 13/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.5236 - auc: 0.8417 - loss: 1.2297 - precision: 0.7442 - recall: 0.3009 - val_accuracy: 0.4963 - val_auc: 0.8187 - val_loss: 1.3239 - val_precision: 0.6876 - val_recall: 0.3177
# Epoch 14/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5453 - auc: 0.8575 - loss: 1.1740 - precision: 0.7547 - recall: 0.3327 - val_accuracy: 0.4960 - val_auc: 0.8154 - val_loss: 1.3584 - val_precision: 0.6510 - val_recall: 0.3040
# Epoch 15/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.5518 - auc: 0.8600 - loss: 1.1639 - precision: 0.7556 - recall: 0.3422 - val_accuracy: 0.5160 - val_auc: 0.8256 - val_loss: 1.3049 - val_precision: 0.7203 - val_recall: 0.2910
# Epoch 16/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.5428 - auc: 0.8572 - loss: 1.1749 - precision: 0.7552 - recall: 0.3225 - val_accuracy: 0.4827 - val_auc: 0.8089 - val_loss: 1.3477 - val_precision: 0.6725 - val_recall: 0.2683
# Epoch 17/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5568 - auc: 0.8625 - loss: 1.1548 - precision: 0.7571 - recall: 0.3345 - val_accuracy: 0.4530 - val_auc: 0.7904 - val_loss: 1.4623 - val_precision: 0.5780 - val_recall: 0.2790
# Epoch 18/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5580 - auc: 0.8661 - loss: 1.1366 - precision: 0.7587 - recall: 0.3503 - val_accuracy: 0.5007 - val_auc: 0.8207 - val_loss: 1.3319 - val_precision: 0.7100 - val_recall: 0.2620
# Epoch 19/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.5555 - auc: 0.8636 - loss: 1.1503 - precision: 0.7360 - recall: 0.3246 - val_accuracy: 0.4783 - val_auc: 0.8058 - val_loss: 1.3843 - val_precision: 0.6329 - val_recall: 0.2873
# Epoch 20/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5657 - auc: 0.8716 - loss: 1.1168 - precision: 0.7546 - recall: 0.3566 - val_accuracy: 0.4960 - val_auc: 0.8157 - val_loss: 1.3699 - val_precision: 0.6895 - val_recall: 0.3057
# Epoch 21/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.5631 - auc: 0.8704 - loss: 1.1217 - precision: 0.7695 - recall: 0.3566 - val_accuracy: 0.5113 - val_auc: 0.8242 - val_loss: 1.3428 - val_precision: 0.6917 - val_recall: 0.3103
# Epoch 22/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.5745 - auc: 0.8774 - loss: 1.0974 - precision: 0.7607 - recall: 0.3690 - val_accuracy: 0.4827 - val_auc: 0.8065 - val_loss: 1.4451 - val_precision: 0.6486 - val_recall: 0.3543
# Epoch 23/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5848 - auc: 0.8830 - loss: 1.0695 - precision: 0.7760 - recall: 0.3918 - val_accuracy: 0.4797 - val_auc: 0.8046 - val_loss: 1.4543 - val_precision: 0.6571 - val_recall: 0.3213
# Epoch 24/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 0.5813 - auc: 0.8840 - loss: 1.0620 - precision: 0.7765 - recall: 0.3867 - val_accuracy: 0.4600 - val_auc: 0.7910 - val_loss: 1.5398 - val_precision: 0.6259 - val_recall: 0.3207
# Epoch 25/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.6074 - auc: 0.8922 - loss: 1.0321 - precision: 0.7780 - recall: 0.4089 - val_accuracy: 0.4600 - val_auc: 0.8006 - val_loss: 1.4586 - val_precision: 0.5878 - val_recall: 0.2947
# Epoch 26/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.5892 - auc: 0.8880 - loss: 1.0484 - precision: 0.7717 - recall: 0.4020 - val_accuracy: 0.4887 - val_auc: 0.8112 - val_loss: 1.3970 - val_precision: 0.6941 - val_recall: 0.2753
# Epoch 27/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.5966 - auc: 0.8921 - loss: 1.0245 - precision: 0.7919 - recall: 0.4037 - val_accuracy: 0.4663 - val_auc: 0.7935 - val_loss: 1.5201 - val_precision: 0.6199 - val_recall: 0.3360
# Epoch 28/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.5882 - auc: 0.8888 - loss: 1.0449 - precision: 0.7672 - recall: 0.4101 - val_accuracy: 0.4653 - val_auc: 0.7972 - val_loss: 1.4487 - val_precision: 0.6918 - val_recall: 0.2783
# Epoch 29/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.6104 - auc: 0.9023 - loss: 0.9830 - precision: 0.8016 - recall: 0.4206 - val_accuracy: 0.5080 - val_auc: 0.8158 - val_loss: 1.4445 - val_precision: 0.6341 - val_recall: 0.3587
# Epoch 30/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6272 - auc: 0.9076 - loss: 0.9567 - precision: 0.7997 - recall: 0.4506 - val_accuracy: 0.4630 - val_auc: 0.7871 - val_loss: 1.5244 - val_precision: 0.6419 - val_recall: 0.2940
# Epoch 31/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.6228 - auc: 0.9054 - loss: 0.9651 - precision: 0.7952 - recall: 0.4412 - val_accuracy: 0.4607 - val_auc: 0.7858 - val_loss: 1.6713 - val_precision: 0.6128 - val_recall: 0.3413
# Epoch 32/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 0.6174 - auc: 0.9037 - loss: 0.9777 - precision: 0.7960 - recall: 0.4373 - val_accuracy: 0.4190 - val_auc: 0.7664 - val_loss: 1.6014 - val_precision: 0.6279 - val_recall: 0.2413
# Epoch 33/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.6183 - auc: 0.9063 - loss: 0.9577 - precision: 0.7901 - recall: 0.4467 - val_accuracy: 0.4853 - val_auc: 0.8026 - val_loss: 1.4856 - val_precision: 0.6593 - val_recall: 0.3103
# Epoch 34/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6416 - auc: 0.9157 - loss: 0.9128 - precision: 0.8122 - recall: 0.4569 - val_accuracy: 0.4993 - val_auc: 0.8077 - val_loss: 1.5455 - val_precision: 0.5980 - val_recall: 0.3560
# Epoch 35/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.6287 - auc: 0.9077 - loss: 0.9516 - precision: 0.8067 - recall: 0.4489 - val_accuracy: 0.4887 - val_auc: 0.8065 - val_loss: 1.5119 - val_precision: 0.6250 - val_recall: 0.3133
# Epoch 36/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.6136 - auc: 0.9041 - loss: 0.9684 - precision: 0.7921 - recall: 0.4493 - val_accuracy: 0.5027 - val_auc: 0.8127 - val_loss: 1.4790 - val_precision: 0.6392 - val_recall: 0.3443
# Epoch 37/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.6599 - auc: 0.9222 - loss: 0.8819 - precision: 0.8189 - recall: 0.4766 - val_accuracy: 0.4513 - val_auc: 0.7761 - val_loss: 1.8993 - val_precision: 0.5078 - val_recall: 0.3673
# Epoch 38/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.6325 - auc: 0.9109 - loss: 0.9425 - precision: 0.7963 - recall: 0.4701 - val_accuracy: 0.4000 - val_auc: 0.7457 - val_loss: 1.6864 - val_precision: 0.6054 - val_recall: 0.2163
# Epoch 39/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.6314 - auc: 0.9101 - loss: 0.9416 - precision: 0.7948 - recall: 0.4547 - val_accuracy: 0.4583 - val_auc: 0.7825 - val_loss: 1.7388 - val_precision: 0.5759 - val_recall: 0.3440
# Epoch 40/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.6440 - auc: 0.9201 - loss: 0.8854 - precision: 0.7994 - recall: 0.4803 - val_accuracy: 0.3690 - val_auc: 0.7293 - val_loss: 1.7261 - val_precision: 0.5409 - val_recall: 0.2050
# Epoch 41/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6464 - auc: 0.9117 - loss: 0.9276 - precision: 0.8015 - recall: 0.4649 - val_accuracy: 0.4637 - val_auc: 0.7885 - val_loss: 1.6472 - val_precision: 0.6261 - val_recall: 0.2980
# Epoch 42/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 0.6646 - auc: 0.9248 - loss: 0.8589 - precision: 0.8186 - recall: 0.4922 - val_accuracy: 0.4637 - val_auc: 0.7855 - val_loss: 1.6913 - val_precision: 0.5977 - val_recall: 0.3263
# Epoch 43/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.6709 - auc: 0.9300 - loss: 0.8336 - precision: 0.8261 - recall: 0.5080 - val_accuracy: 0.4847 - val_auc: 0.7983 - val_loss: 1.6930 - val_precision: 0.5994 - val_recall: 0.3617
# Epoch 44/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.6505 - auc: 0.9202 - loss: 0.8892 - precision: 0.7984 - recall: 0.5078 - val_accuracy: 0.4677 - val_auc: 0.7901 - val_loss: 1.7918 - val_precision: 0.5648 - val_recall: 0.3560
# Epoch 45/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.6888 - auc: 0.9335 - loss: 0.8118 - precision: 0.8311 - recall: 0.5378 - val_accuracy: 0.4553 - val_auc: 0.7727 - val_loss: 1.9855 - val_precision: 0.5280 - val_recall: 0.3430
# Epoch 46/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.6809 - auc: 0.9331 - loss: 0.8117 - precision: 0.8166 - recall: 0.5346 - val_accuracy: 0.4460 - val_auc: 0.7722 - val_loss: 1.9384 - val_precision: 0.5509 - val_recall: 0.3247
# Epoch 47/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.6808 - auc: 0.9306 - loss: 0.8303 - precision: 0.8107 - recall: 0.5298 - val_accuracy: 0.4607 - val_auc: 0.7809 - val_loss: 1.8261 - val_precision: 0.5815 - val_recall: 0.3317
# Epoch 48/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.6939 - auc: 0.9345 - loss: 0.8047 - precision: 0.8186 - recall: 0.5445 - val_accuracy: 0.4057 - val_auc: 0.7398 - val_loss: 2.2032 - val_precision: 0.4925 - val_recall: 0.3270
# Epoch 49/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.6749 - auc: 0.9317 - loss: 0.8216 - precision: 0.8062 - recall: 0.5380 - val_accuracy: 0.4470 - val_auc: 0.7845 - val_loss: 1.6839 - val_precision: 0.5606 - val_recall: 0.3193
# Epoch 50/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6921 - auc: 0.9365 - loss: 0.7920 - precision: 0.8167 - recall: 0.5540 - val_accuracy: 0.4633 - val_auc: 0.7853 - val_loss: 1.8139 - val_precision: 0.5613 - val_recall: 0.3630
# Epoch 51/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.7064 - auc: 0.9420 - loss: 0.7587 - precision: 0.8312 - recall: 0.5750 - val_accuracy: 0.4147 - val_auc: 0.7457 - val_loss: 2.1759 - val_precision: 0.4981 - val_recall: 0.3003
# Epoch 52/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.6876 - auc: 0.9327 - loss: 0.8165 - precision: 0.8013 - recall: 0.5570 - val_accuracy: 0.4373 - val_auc: 0.7666 - val_loss: 1.9185 - val_precision: 0.5238 - val_recall: 0.3377
# Epoch 53/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.6789 - auc: 0.9311 - loss: 0.8269 - precision: 0.8000 - recall: 0.5527 - val_accuracy: 0.4410 - val_auc: 0.7594 - val_loss: 2.2146 - val_precision: 0.4924 - val_recall: 0.3577
# Epoch 54/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.6933 - auc: 0.9340 - loss: 0.8091 - precision: 0.8141 - recall: 0.5592 - val_accuracy: 0.4440 - val_auc: 0.7634 - val_loss: 2.1108 - val_precision: 0.5249 - val_recall: 0.3370
# Epoch 55/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.7153 - auc: 0.9449 - loss: 0.7396 - precision: 0.8322 - recall: 0.5858 - val_accuracy: 0.4183 - val_auc: 0.7586 - val_loss: 2.0753 - val_precision: 0.4820 - val_recall: 0.3297
# Epoch 56/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 0.7024 - auc: 0.9407 - loss: 0.7657 - precision: 0.8197 - recall: 0.5820 - val_accuracy: 0.4343 - val_auc: 0.7716 - val_loss: 1.9782 - val_precision: 0.5042 - val_recall: 0.3373
# Epoch 57/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.6875 - auc: 0.9335 - loss: 0.8130 - precision: 0.8093 - recall: 0.5665 - val_accuracy: 0.4403 - val_auc: 0.7626 - val_loss: 2.0972 - val_precision: 0.5295 - val_recall: 0.3500
# Epoch 58/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.7089 - auc: 0.9431 - loss: 0.7496 - precision: 0.8187 - recall: 0.5849 - val_accuracy: 0.4290 - val_auc: 0.7611 - val_loss: 2.0471 - val_precision: 0.5313 - val_recall: 0.3137
# Epoch 59/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.7223 - auc: 0.9479 - loss: 0.7256 - precision: 0.8397 - recall: 0.5994 - val_accuracy: 0.4577 - val_auc: 0.7787 - val_loss: 1.9401 - val_precision: 0.5540 - val_recall: 0.3657
# Epoch 60/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.7216 - auc: 0.9475 - loss: 0.7220 - precision: 0.8332 - recall: 0.6086 - val_accuracy: 0.4613 - val_auc: 0.7862 - val_loss: 1.8445 - val_precision: 0.5529 - val_recall: 0.3430
# Epoch 61/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.7200 - auc: 0.9448 - loss: 0.7451 - precision: 0.8317 - recall: 0.5842 - val_accuracy: 0.4457 - val_auc: 0.7737 - val_loss: 1.9184 - val_precision: 0.5398 - val_recall: 0.3410
# Epoch 62/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.7373 - auc: 0.9524 - loss: 0.6940 - precision: 0.8480 - recall: 0.6243 - val_accuracy: 0.4297 - val_auc: 0.7563 - val_loss: 2.1982 - val_precision: 0.4953 - val_recall: 0.3353
# Epoch 63/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.7174 - auc: 0.9474 - loss: 0.7216 - precision: 0.8260 - recall: 0.6100 - val_accuracy: 0.4100 - val_auc: 0.7599 - val_loss: 1.9141 - val_precision: 0.4921 - val_recall: 0.3130
# Epoch 64/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.7082 - auc: 0.9434 - loss: 0.7461 - precision: 0.8082 - recall: 0.6077 - val_accuracy: 0.4397 - val_auc: 0.7702 - val_loss: 2.0843 - val_precision: 0.5016 - val_recall: 0.3583
# Epoch 65/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.7001 - auc: 0.9398 - loss: 0.7704 - precision: 0.8050 - recall: 0.5962 - val_accuracy: 0.4510 - val_auc: 0.7736 - val_loss: 2.0520 - val_precision: 0.5207 - val_recall: 0.3527
# Epoch 66/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7252 - auc: 0.9486 - loss: 0.7111 - precision: 0.8262 - recall: 0.6109 - val_accuracy: 0.4530 - val_auc: 0.7745 - val_loss: 2.0228 - val_precision: 0.5360 - val_recall: 0.3693
# Epoch 67/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.7305 - auc: 0.9512 - loss: 0.6963 - precision: 0.8306 - recall: 0.6287 - val_accuracy: 0.4120 - val_auc: 0.7551 - val_loss: 2.1131 - val_precision: 0.4916 - val_recall: 0.3220
# Epoch 68/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7462 - auc: 0.9549 - loss: 0.6715 - precision: 0.8439 - recall: 0.6424 - val_accuracy: 0.4383 - val_auc: 0.7672 - val_loss: 2.1384 - val_precision: 0.5079 - val_recall: 0.3637
# Epoch 69/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7271 - auc: 0.9485 - loss: 0.7134 - precision: 0.8180 - recall: 0.6273 - val_accuracy: 0.4607 - val_auc: 0.7752 - val_loss: 2.1457 - val_precision: 0.5245 - val_recall: 0.3753
# Epoch 70/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7416 - auc: 0.9525 - loss: 0.6906 - precision: 0.8364 - recall: 0.6339 - val_accuracy: 0.4323 - val_auc: 0.7676 - val_loss: 2.1451 - val_precision: 0.5041 - val_recall: 0.3493
# Epoch 71/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.7488 - auc: 0.9561 - loss: 0.6604 - precision: 0.8415 - recall: 0.6588 - val_accuracy: 0.4470 - val_auc: 0.7740 - val_loss: 2.2205 - val_precision: 0.5201 - val_recall: 0.3790
# Epoch 72/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7603 - auc: 0.9596 - loss: 0.6333 - precision: 0.8505 - recall: 0.6643 - val_accuracy: 0.4050 - val_auc: 0.7526 - val_loss: 2.1595 - val_precision: 0.4561 - val_recall: 0.3200
# Epoch 73/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.7316 - auc: 0.9493 - loss: 0.7095 - precision: 0.8191 - recall: 0.6389 - val_accuracy: 0.4400 - val_auc: 0.7683 - val_loss: 2.1910 - val_precision: 0.5025 - val_recall: 0.3623
# Epoch 74/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.7506 - auc: 0.9540 - loss: 0.6780 - precision: 0.8333 - recall: 0.6594 - val_accuracy: 0.3763 - val_auc: 0.7380 - val_loss: 2.2147 - val_precision: 0.4616 - val_recall: 0.2883
# Epoch 75/200
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 17s 39ms/step - accuracy: 0.7578 - auc: 0.9592 - loss: 0.6377 - precision: 0.8434 - recall: 0.6613 - val_accuracy: 0.3990 - val_auc: 0.7353 - val_loss: 2.4840 - val_precision: 0.4616 - val_recall: 0.3423
# Epoch 76/200
# 261/439 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7664 - auc: 0.9599 - loss: 0.6397 - precision: 0.8465 - recall: 0.6764
